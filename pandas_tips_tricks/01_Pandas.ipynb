# %% [markdown]
# # Pandas (Day-1)

# %%
# import Pandas
    
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.0'

# %%
# Read the CSV file


# df=pd.read_csv('../pandas_tips_tricks/pakistan_data.csv', encoding='utf-8')

df_pkPopulation= pd.read_csv('./pakistan_data.csv', encoding='utf-8')
df_pkPopulation.head(100)
# Out:
#    PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0    PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1    PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2    PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3    PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4    PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
# ..      ...                  ...                    ...                  ...
# 95   PUNJAB      MULTAN DIVISION        VEHARI DISTRICT        MAILSI TEHSIL
# 96   PUNJAB      MULTAN DIVISION        VEHARI DISTRICT        VEHARI TEHSIL
# 97   PUNJAB  RAWALPINDI DIVISION        ATTOCK DISTRICT        ATTOCK TEHSIL
# 98   PUNJAB  RAWALPINDI DIVISION        ATTOCK DISTRICT    FATEH JANG TEHSIL
# 99   PUNJAB  RAWALPINDI DIVISION        ATTOCK DISTRICT   HASAN ABDAL TEHSIL
#
# ...

# %%
# Write a DataFrame to a CSV file

# df_pkPopulation.to_csv('./pk_data.csv', index=False, header=True)

# write a file into excel file

# df_pkPopulation.to_excel('./pk_data.xlsx', index=False)

# df_pkPopulation.to_excel('./pk_data1.xlsx', index=False,header=True)

# if you want to read the excel file

# pd.read_excel('./pk_data1.xlsx', sheet_name='Sheet1') # sheet_name is optional, if you have only one sheet then you can skip it

# %%
df_pkPopulation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PROVINCE                    528 non-null    object
#  1   DIVISION                    528 non-null    object
#  2   DISTRICT                    528 non-null    object
#  3   SUB DIVISION                528 non-null    object
#  4   AREA (sq.km)                528 non-null    float64
#  5   ALL SEXES (RURAL)           528 non-null    int64
#  6   MALE (RURAL)                528 non-null    int64
#  7   FEMALE (RURAL)              528 non-null    int64
#  8   TRANSGENDER (RURAL)         528 non-null    int64
#  9   SEX RATIO (RURAL)           528 non-null    float64
#  10  AVG HOUSEHOLD SIZE (RURAL)  528 non-null    float64
#  11  POPULATION 1998 (RURAL)     528 non-null    int64
#  12  ANNUAL GROWTH RATE (RURAL)  528 non-null    float64
# ...

# %%
# to find the number of cell in dataDFram (rows, columns)
528*21 # (528 rows, 21 columns)
# Out:
# 11088

# %%
df_pkPopulation.head(100)
# Out:
# <bound method DataFrame.info of      PROVINCE                   DIVISION                   DISTRICT  \
# 0      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 1      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 2      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 3      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 4      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# ..        ...                        ...                        ...
# 523  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 524  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 525  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 526  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 527  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
#
#             SUB DIVISION  AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  \
# ...

# %%
df_pkPopulation.tail(100)
# Out:
#      PROVINCE                   DIVISION                   DISTRICT  \
# 428       KPK            HAZARA DIVISION          MANSEHRA DISTRICT
# 429       KPK            HAZARA DIVISION          MANSEHRA DISTRICT
# 430       KPK            HAZARA DIVISION           TORGHAR DISTRICT
# 431       KPK            HAZARA DIVISION           TORGHAR DISTRICT
# 432       KPK            HAZARA DIVISION          KOHISTAN DISTRICT
# ..        ...                        ...                        ...
# 523  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 524  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 525  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 526  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 527  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
#
#           SUB DIVISION  AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  \
# 428    MANSEHRA TEHSIL        1340.0             872623        436662
# ...

# %%
df_pkPopulation.describe() # it will give you the summary of the data, like count, mean, std, min, 25%, 50%, 75%, max
# Out:
#        AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# count    528.000000       5.280000e+02  5.280000e+02    5.280000e+02
# mean    1492.005871       2.462780e+05  1.252757e+05    1.209841e+05
# std     2039.453778       2.711898e+05  1.375630e+05    1.337169e+05
# min        0.000000       0.000000e+00  0.000000e+00    0.000000e+00
# 25%      425.000000       5.093450e+04  2.712725e+04    2.397900e+04
# 50%      882.000000       1.652410e+05  8.413450e+04    8.204400e+04
# 75%     1734.250000       3.129112e+05  1.605022e+05    1.522190e+05
# max    18374.000000       2.297375e+06  1.172995e+06    1.124167e+06
#
#        TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# count           528.000000         528.000000                  528.000000
# mean             18.174242          98.982614                    6.277064
# std              25.522248          26.812660                    2.074947
# ...

# %%
df_pkPopulation.loc[df_pkPopulation['AREA (sq.km)'].idxmin()]
# Out:
# PROVINCE                                   BALOCHISTAN
# DIVISION                                 Zhob Division
# DISTRICT                      KILLA SAIFULLAH DISTRICT
# SUB DIVISION                         BADINI SUB-TEHSIL
# AREA (sq.km)                                       0.0
# ALL SEXES (RURAL)                                15345
# MALE (RURAL)                                      8720
# FEMALE (RURAL)                                    6625
# TRANSGENDER (RURAL)                                  0
# SEX RATIO (RURAL)                               131.62
# AVG HOUSEHOLD SIZE (RURAL)                        6.89
# POPULATION 1998 (RURAL)                           6583
# ANNUAL GROWTH RATE (RURAL)                        4.55
# ALL SEXES (URBAN)                                    0
# MALE (URBAN)                                         0
# FEMALE (URBAN)                                       0
# TRANSGENDER (URBAN)                                  0
# ...

# %%
res= df_pkPopulation.loc[(df_pkPopulation['TRANSGENDER (RURAL)']==49 | ((df_pkPopulation['ANNUAL GROWTH RATE (RURAL)'] > 2.04) |
 (df_pkPopulation['ANNUAL GROWTH RATE (RURAL)'] < 3.0))), ['DIVISION']] # it will give you the row where the
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 res= df_pkPopulation.loc[(df_pkPopulation['TRANSGENDER (RURAL)']==49 | ((df_pkPopulation['ANNUAL GROWTH RATE (RURAL)'] > 2.04) |
#       2  (df_pkPopulation['ANNUAL GROWTH RATE (RURAL)'] < 3.0))), ['DIVISION']] # it will give you the row where the
#
# NameError: name 'df_pkPopulation' is not defined

# %%
print(res.count())
# Out:
# DIVISION    37
# dtype: int64

# %%
df_pkPopulation.loc[df_pkPopulation['AREA (sq.km)']> 18370.0]
# Out:
#    PROVINCE             DIVISION             DISTRICT   SUB DIVISION  \
# 10   PUNJAB  BAHAWALPUR DIVISION  BAHAWALPUR DISTRICT  YAZMAN TEHSIL
#
#     AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 10       18374.0             564422        288761          275612
#
#     TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# 10                   49             104.77  ...                   385770
#
#     ANNUAL GROWTH RATE (RURAL)  ALL SEXES (URBAN)  MALE (URBAN)  \
# 10                        2.02              48883         24884
#
#     FEMALE (URBAN)  TRANSGENDER (URBAN)  SEX RATIO (URBAN)  \
# 10           23995                    4              103.7
#
#     AVG HOUSEHOLD SIZE (URBAN)  POPULATION 1998 (URBAN)  \
# 10                        6.18                    21028
#
#     ANNUAL GROWTH RATE (URBAN)
# 10                        4.53
#
# [1 rows x 21 columns]

# %%
print(df_pkPopulation.columns)
# Out:
# Index(['PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION', 'AREA (sq.km)',
#        'ALL SEXES (RURAL)', 'MALE (RURAL)', 'FEMALE (RURAL)',
#        'TRANSGENDER (RURAL)', 'SEX RATIO (RURAL)',
#        'AVG HOUSEHOLD SIZE (RURAL)', 'POPULATION 1998 (RURAL)',
#        'ANNUAL GROWTH RATE (RURAL)', 'ALL SEXES (URBAN)', 'MALE (URBAN)',
#        'FEMALE (URBAN)', 'TRANSGENDER (URBAN)', 'SEX RATIO (URBAN)',
#        'AVG HOUSEHOLD SIZE (URBAN)', 'POPULATION 1998 (URBAN)',
#        'ANNUAL GROWTH RATE (URBAN)'],
#       dtype='object')
